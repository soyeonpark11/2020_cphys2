# %%
for i in range(9):
    for j in range(9):
        print ((i+j)*(i+j))
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
